# %% [markdown]
# <a href="https://colab.research.google.com/github/Maviya5/CE888/blob/master/Assignment%202/Final_CE_888.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## importing the libraries
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import os
import matplotlib.pyplot as plt
get_ipython().magic('matplotlib inline')

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import roc_auc_score


## reading files
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    id   timestamp  full_sq  ...  sport_count_5000  market_count_5000  price_doc
# 0   1  2011-08-20       43  ...                52                  4    5850000
# 1   2  2011-08-23       34  ...                66                 14    6000000
# 2   3  2011-08-27       43  ...                67                 10    5700000
# 3   4  2011-09-01       89  ...                26                  3   13100000
# 4   5  2011-09-05       77  ...               195                 14   16331452
#
# [5 rows x 292 columns]

# %%
test.head()
# Out:
#       id   timestamp  ...  sport_count_5000  market_count_5000
# 0  30474  2015-07-01  ...                14                  1
# 1  30475  2015-07-01  ...                12                  1
# 2  30476  2015-07-01  ...                71                 11
# 3  30477  2015-07-01  ...                 2                  0
# 4  30478  2015-07-01  ...                11                  1
#
# [5 rows x 291 columns]

# %%
#### Preprocessing This step involves imputing all missing values and label encoding of all categorical variables.####

## missing values
for i in train.columns:
    if train[i].dtype == 'object':
      train[i] = train[i].fillna(train[i].mode().iloc[0])
    if (train[i].dtype == 'int' or train[i].dtype == 'float'):
      train[i] = train[i].fillna(np.mean(train[i]))


for i in test.columns:
    if test[i].dtype == 'object':
      test[i] = test[i].fillna(test[i].mode().iloc[0])
    if (test[i].dtype == 'int' or test[i].dtype == 'float'):
      test[i] = test[i].fillna(np.mean(test[i]))

## label encoding
number = LabelEncoder()
for i in train.columns:
    if (train[i].dtype == 'object'):
      train[i] = number.fit_transform(train[i].astype('str'))
      train[i] = train[i].astype('object')

for i in test.columns:
    if (test[i].dtype == 'object'):
      test[i] = number.fit_transform(test[i].astype('str'))
      test[i] = test[i].astype('object')

# %% [markdown]
# Finding the accuracy on the training using the Random Forest model

# %%
X=train.iloc[:,:-1]
y=train.iloc[:,-1]


## Split the data into training and testing sets
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.25, random_state = 42)

## Instantiating the model
rf = RandomForestRegressor(n_estimators = 200, random_state = 42)

# Fitting the model
rf.fit(X_train, y_train);

# %%
predictions = rf.predict(X_test)
##Calculating the training accuracy
print("Training Accuracy = ", rf.score(X_train, y_train))


#errors = abs(predictions - y_test)
# Calculate mean absolute percentage error (MAPE)
#mape = 100 * (errors / y_test)
# Calculate and display accuracy
#accuracy = 100 - np.mean(mape)
#print('Accuracy for training before the dropping of features:', round(accuracy, 2), '%.')
# Out:
# Training Accuracy =  0.9548598900162178

# %%
## creating a new feature named 'origin'
train['origin'] = 0
test['origin'] = 1
training = train.drop('price_doc',axis=1) #droping target variable

# %%
## taking sample from training and test data
training = training.sample(7662, random_state=12)
testing = test.sample(7000, random_state=11)

# %%
## combining random samples
combi = training.append(testing)
y = combi['origin']
combi.drop('origin',axis=1,inplace=True)

# %%
## modelling
model = RandomForestClassifier(n_estimators = 50, max_depth = 5,min_samples_leaf = 5)
drop_list = []
for i in combi.columns:
  score = cross_val_score(model,pd.DataFrame(combi[i]),y,cv=2,scoring='roc_auc')
  #The value of AUC-ROC for a particular feature is greater than 0.80, we classify that feature as drifting.
  if (np.mean(score) > 0.80):
    drop_list.append(i)
  print(i,np.mean(score))
# Out:
# id 1.0
# timestamp 0.95988268635567
# full_sq 0.7095534176082335
# life_sq 0.8672706119252712
# floor 0.516119662900399
# max_floor 0.6769267069396279
# material 0.6691530372524891
# build_year 0.8011390349405227
# num_room 0.6618084051161577
# kitch_sq 0.8965650147294627
# state 0.765498844016855
# product_type 0.5084359175150093
# sub_area 0.6737132788902562
# area_m 0.5974958235447664
# raion_popul 0.5979503113696536
# green_zone_part 0.6045059663646195
# indust_part 0.5957491516575306
# children_preschool 0.596912984301003
# preschool_quota 0.7333315807137264
# preschool_education_centers_raion 0.5114792668829473
# children_school 0.5922277100346796
# school_quota 0.7349690121937578
# school_education_centers_raion 0.5282194130588806
# school_education_centers_top_20_raion 0.5014311444233135
# hospital_beds_raion 0.8837626132677032
# healthcare_centers_raion 0.5279273781556476
# university_top_20_raion 0.5004552336204646
# sport_objects_raion 0.5377006376552187
# additional_education_raion 0.5393302569265764
# culture_objects_top_25 0.5135804713428049
# culture_objects_top_25_raion 0.5117449752022971
# shopping_centers_raion 0.5675908192564418
# office_raion 0.5212562180706268
# thermal_power_plant_raion 0.5007810157735764
# incineration_raion 0.5229840959093113
# oil_chemistry_raion 0.5007046835962263
# radiation_raion 0.5063736808740724
# railroad_terminal_raion 0.5025013797218183
# big_market_raion 0.5108660364694038
# nuclear_reactor_raion 0.5027774918894732
# detention_facility_raion 0.4963597717865533
# full_all 0.5906489540217026
# male_f 0.5899796024909572
# female_f 0.5898299958981243
# young_all 0.5984772905246671
# young_male 0.5989845060968788
# young_female 0.5975885818697095
# work_all 0.6012545027407987
# work_male 0.5987438378640415
# work_female 0.593828187343849
# ekder_all 0.5957366222918299
# ekder_male 0.6030322183689452
# ekder_female 0.5948901629563337
# 0_6_all 0.5970436290412797
# 0_6_male 0.596302904873774
# 0_6_female 0.5974354886825521
# 7_14_all 0.5926245665063206
# 7_14_male 0.5956437334526606
# 7_14_female 0.593528787709289
# 0_17_all 0.6002474176828132
# 0_17_male 0.5987716001044114
# 0_17_female 0.5973555953313197
# 16_29_all 0.5986936271767909
# 16_29_male 0.5939032889584965
# 16_29_female 0.6023622142670695
# 0_13_all 0.5992693254279002
# 0_13_male 0.5977997911772384
# 0_13_female 0.5982426445911175
# raion_build_count_with_material_info 0.7040247977029497
# build_count_block 0.6894433941156729
# build_count_wood 0.6836871574001566
# build_count_frame 0.6663027370697692
# build_count_brick 0.7061421486370586
# build_count_monolith 0.6820726591341313
# build_count_panel 0.6982716746839691
# build_count_foam 0.6501203527613081
# build_count_slag 0.6769730767796547
# build_count_mix 0.6702674982287355
# raion_build_count_with_builddate_info 0.7049268933885222
# build_count_before_1920 0.6806891524033263
# build_count_1921-1945 0.6776363873662228
# build_count_1946-1970 0.6992091770145803
# build_count_1971-1995 0.6912864414364024
# build_count_after_1995 0.6958137934892046
# ID_metro 0.5901571204832755
# metro_min_avto 0.6230810866241563
# metro_km_avto 0.6226572137077226
# metro_min_walk 0.6096445724726853
# metro_km_walk 0.611256143491069
# kindergarten_km 0.6071131371890965
# school_km 0.6203172241488608
# park_km 0.6203256702837752
# green_zone_km 0.5796788044896894
# industrial_km 0.6087595555058358
# water_treatment_km 0.6309450908006116
# cemetery_km 0.6063837491143678
# incineration_km 0.6226072640489242
# railroad_station_walk_km 0.6218901629563336
# railroad_station_walk_min 0.622103963903494
# ID_railroad_station_walk 0.600339225118395
# railroad_station_avto_km 0.6217103702875042
# railroad_station_avto_min 0.6051849013685349
# ID_railroad_station_avto 0.5907218368945073
# public_transport_station_km 0.6048586158034083
# public_transport_station_min_walk 0.6057664727598164
# water_km 0.5983101204459857
# water_1line 0.4982019427974792
# mkad_km 0.6227736696871387
# ttk_km 0.6143677331543423
# sadovoe_km 0.6226711973747996
# bulvar_ring_km 0.618662452921654
# kremlin_km 0.6180379796397808
# big_road1_km 0.5899422754223067
# ID_big_road1 0.5752866092404072
# big_road1_1line 0.5087784054890554
# big_road2_km 0.6070033747249879
# ID_big_road2 0.5864617966215461
# railroad_km 0.6210453070813291
# railroad_1line 0.5010314352835887
# zd_vokzaly_avto_km 0.634486650259164
# ID_railroad_terminal 0.5471611104896148
# bus_terminal_avto_km 0.6137722526755416
# ID_bus_terminal 0.5695960771152627
# oil_chemistry_km 0.6257914009769922
# nuclear_reactor_km 0.6283038371182459
# radiation_km 0.6277762613267703
# power_transmission_line_km 0.6129768244024314
# thermal_power_plant_km 0.6362400902412648
# ts_km 0.6252501025468918
# big_market_km 0.6180639706156543
# market_shop_km 0.6128421896558154
# fitness_km 0.621062553604057
# swim_pool_km 0.6226898609091247
# ice_rink_km 0.600976339635306
# stadium_km 0.6097099041652683
# basketball_km 0.6224936607375918
# hospice_morgue_km 0.6058229294850281
# detention_facility_km 0.626459447365477
# public_healthcare_km 0.6103498899951523
# university_km 0.6185117276354551
# workplaces_km 0.6254427228996533
# shopping_centers_km 0.6195896632732968
# office_km 0.628604299511504
# additional_education_km 0.6153551105641943
# preschool_km 0.6166833724876012
# big_church_km 0.6171554237983369
# church_synagogue_km 0.5944407838311518
# mosque_km 0.6178757504567998
# theater_km 0.6266964425550956
# museum_km 0.6312733900137972
# exhibition_km 0.61716754297647
# catering_km 0.6167578401760078
# ecology 0.529867714509453
# green_part_500 0.5895392102024835
# prom_part_500 0.5941815452884365
# office_count_500 0.5110838274229034
# office_sqm_500 0.5162982063616363
# trc_count_500 0.5263063728232091
# trc_sqm_500 0.5292771562814633
# cafe_count_500 0.5221119998508408
# cafe_sum_500_min_price_avg 0.8431981765298131
# cafe_sum_500_max_price_avg 0.845239624119029
# cafe_avg_price_500 0.8448638363724503
# cafe_count_500_na_price 0.49938869001006814
# cafe_count_500_price_500 0.502978092254913
# cafe_count_500_price_1000 0.517370884140657
# cafe_count_500_price_1500 0.5028146325092292
# cafe_count_500_price_2500 0.5034494350598501
# cafe_count_500_price_4000 0.49772437259947044
# cafe_count_500_price_high 0.5019900436290413
# big_church_count_500 0.5026789350039155
# church_count_500 0.5114428347689898
# mosque_count_500 0.49823897154789876
# leisure_count_500 0.5057357086922475
# sport_count_500 0.5147332102770631
# market_count_500 0.5033295670656673
# green_part_1000 0.5981917440429578
# prom_part_1000 0.5832711712719543
# office_count_1000 0.5125173770369542
# office_sqm_1000 0.5327631912592758
# trc_count_1000 0.5328073237125703
# trc_sqm_1000 0.5669820449714733
# cafe_count_1000 0.5592256218070626
# cafe_sum_1000_min_price_avg 0.7007581757840176
# cafe_sum_1000_max_price_avg 0.6978286348211955
# cafe_avg_price_1000 0.700149438788828
# cafe_count_1000_na_price 0.5118822761681023
# cafe_count_1000_price_500 0.5285842562553604
# cafe_count_1000_price_1000 0.5402242607301337
# cafe_count_1000_price_1500 0.5109952641980833
# cafe_count_1000_price_2500 0.5254191744042958
# cafe_count_1000_price_4000 0.5126827944960288
# cafe_count_1000_price_high 0.5033083491814894
# big_church_count_1000 0.5203845135548346
# church_count_1000 0.5310434425923856
# mosque_count_1000 0.4979347428869747
# leisure_count_1000 0.508506544356192
# sport_count_1000 0.5327336763992989
# market_count_1000 0.5022866465301861
# green_part_1500 0.6119149233695044
# prom_part_1500 0.6124567811462878
# office_count_1500 0.5143577954282731
# office_sqm_1500 0.5437703881865981
# trc_count_1500 0.5426213782302272
# trc_sqm_1500 0.560173527985979
# cafe_count_1500 0.5731720736846031
# cafe_sum_1500_min_price_avg 0.6703651228698214
# cafe_sum_1500_max_price_avg 0.656136219562218
# cafe_avg_price_1500 0.6778740724167506
# cafe_count_1500_na_price 0.5235945482343289
# cafe_count_1500_price_500 0.5381682141924898
# cafe_count_1500_price_1000 0.5571454487824887
# cafe_count_1500_price_1500 0.5117005444307716
# cafe_count_1500_price_2500 0.5271480963567887
# cafe_count_1500_price_4000 0.5182168214192489
# cafe_count_1500_price_high 0.5061268784726106
# big_church_count_1500 0.5214138233210278
# church_count_1500 0.5158184360666742
# mosque_count_1500 0.5019334936793824
# leisure_count_1500 0.5173441287243166
# sport_count_1500 0.5491739754633254
# market_count_1500 0.5133273296789351
# green_part_2000 0.6032733527240183
# prom_part_2000 0.615959913487713
# office_count_2000 0.540641179102808
# office_sqm_2000 0.5695079427228997
# trc_count_2000 0.5517345527091024
# trc_sqm_2000 0.5688539545810494
# cafe_count_2000 0.5690513107357273
# cafe_sum_2000_min_price_avg 0.6293078457694745
# cafe_sum_2000_max_price_avg 0.6244237051124287
# cafe_avg_price_2000 0.6301145355558042
# cafe_count_2000_na_price 0.5350038594921132
# cafe_count_2000_price_500 0.5474608270872954
# cafe_count_2000_price_1000 0.5600101428198531
# cafe_count_2000_price_1500 0.5144363463474662
# cafe_count_2000_price_2500 0.5387564790990789
# cafe_count_2000_price_4000 0.5298289331394264
# cafe_count_2000_price_high 0.5074170861766789
# big_church_count_2000 0.5156338143714807
# church_count_2000 0.5217059141589291
# mosque_count_2000 0.49657051497184623
# leisure_count_2000 0.5254432449565574
# sport_count_2000 0.5446250326285565
# market_count_2000 0.5195786441436403
# green_part_3000 0.6016565238468137
# prom_part_3000 0.6110378118357759
# office_count_3000 0.5570902785546482
# office_sqm_3000 0.5788669127792072
# trc_count_3000 0.5730573889696835
# trc_sqm_3000 0.6008232278032591
# cafe_count_3000 0.5838994481112727
# cafe_sum_3000_min_price_avg 0.6231741992019988
# cafe_sum_3000_max_price_avg 0.6290647537010106
# cafe_avg_price_3000 0.62956344855875
# cafe_count_3000_na_price 0.5409672782190401
# cafe_count_3000_price_500 0.552502610284521
# cafe_count_3000_price_1000 0.564731028824999
# cafe_count_3000_price_1500 0.5422657456091285
# cafe_count_3000_price_2500 0.5439712122907111
# cafe_count_3000_price_4000 0.5337752545027408
# cafe_count_3000_price_high 0.5104981541559459
# big_church_count_3000 0.5286183391132491
# church_count_3000 0.5560800984450163
# mosque_count_3000 0.49533836745348103
# leisure_count_3000 0.5410115784763396
# sport_count_3000 0.5636459708393929
# market_count_3000 0.5405141701159712
# green_part_5000 0.6142986351940933
# prom_part_5000 0.63091341313346
# office_count_5000 0.5685796696125591
# office_sqm_5000 0.6059763582801954
# trc_count_5000 0.5821039639034941
# trc_sqm_5000 0.616581030689488
# cafe_count_5000 0.6208359995525227
# cafe_sum_5000_min_price_avg 0.6051976358280196
# cafe_sum_5000_max_price_avg 0.6204446060334863
# cafe_avg_price_5000 0.6207975351456165
# cafe_count_5000_na_price 0.5559259424991609
# cafe_count_5000_price_500 0.5666543796845285
# cafe_count_5000_price_1000 0.590178151918559
# cafe_count_5000_price_1500 0.5759128724316664
# cafe_count_5000_price_2500 0.5677847074616847
# cafe_count_5000_price_4000 0.5504707834582541
# cafe_count_5000_price_high 0.5108965581534102
# big_church_count_5000 0.5478770928888392
# church_count_5000 0.5980104038483052
# mosque_count_5000 0.5184950591042996
# leisure_count_5000 0.5534644628407352
# sport_count_5000 0.5850113733825558
# market_count_5000 0.5615608569191185

# %%
## A droplist of features is created which have a drift in them.
 drop_list
# Out:
# ['id',
#  'timestamp',
#  'life_sq',
#  'build_year',
#  'kitch_sq',
#  'hospital_beds_raion',
#  'cafe_sum_500_min_price_avg',
#  'cafe_sum_500_max_price_avg',
#  'cafe_avg_price_500']

# %%
# Import library
import seaborn as sns


 
# Method 1: on the same Axis
sns.distplot( training["material"] , color="skyblue", label="Training Material")
sns.distplot( testing["material"] , color="red", label="Testing Material")
plt.legend()
plt.show()

# %%
#Above graph shows that we have drift in the data
#We will Train our model with drift to check accuracy 

## taking sample from training and test data
train_with_drift = train.sample(7662, random_state=12)
test_with_drift = test.sample(7000, random_state=11)


# Saving feature names for later use
train_with_drift_list = list(train_with_drift.columns)

##converted into an array
train_with_drift = np.array(train_with_drift)

# %% [markdown]
# Remove the drifting by dropping some features

# %%
## The features which have a covariate shift and are not important to the data are dropped
drift_train = train.drop(['id','hospital_beds_raion'], axis=1)
drift_test = test.drop(['id','hospital_beds_raion'], axis=1)

# %%
print(drift_train)
# Out:
#       timestamp  full_sq    life_sq  ...  market_count_5000  price_doc  origin
# 0             0       43  27.000000  ...                  4    5850000       0
# 1             1       34  19.000000  ...                 14    6000000       0
# 2             2       43  29.000000  ...                 10    5700000       0
# 3             3       89  50.000000  ...                  3   13100000       0
# 4             4       77  77.000000  ...                 14   16331452       0
# ...         ...      ...        ...  ...                ...        ...     ...
# 30466      1160       44  27.000000  ...                  6    7400000       0
# 30467      1160       86  59.000000  ...                 15   25000000       0
# 30468      1160       45  34.403271  ...                  1    6970959       0
# 30469      1160       64  32.000000  ...                  7   13500000       0
# 30470      1160       43  28.000000  ...                 10    5600000       0
#
# [30471 rows x 291 columns]

# %% [markdown]
# Finding the accuracy after the dropping of the features with covariate shift. Again a Random Forest model is used here.

# %%
trani=pd.read_csv('train.csv')
print(trani)
# Out:
#           id   timestamp  ...  market_count_5000  price_doc
# 0          1  2011-08-20  ...                  4    5850000
# 1          2  2011-08-23  ...                 14    6000000
# 2          3  2011-08-27  ...                 10    5700000
# 3          4  2011-09-01  ...                  3   13100000
# 4          5  2011-09-05  ...                 14   16331452
# ...      ...         ...  ...                ...        ...
# 30466  30469  2015-06-30  ...                  6    7400000
# 30467  30470  2015-06-30  ...                 15   25000000
# 30468  30471  2015-06-30  ...                  1    6970959
# 30469  30472  2015-06-30  ...                  7   13500000
# 30470  30473  2015-06-30  ...                 10    5600000
#
# [30471 rows x 292 columns]

# %%
#### Preprocessing This step involves imputing all missing values and label encoding of all categorical variables.####

## missing values
for i in trani.columns:
    if trani[i].dtype == 'object':
      trani[i] = trani[i].fillna(trani[i].mode().iloc[0])
    if (trani[i].dtype == 'int' or trani[i].dtype == 'float'):
      trani[i] = trani[i].fillna(np.mean(trani[i]))

## label encoding
number = LabelEncoder()
for i in trani.columns:
    if (trani[i].dtype == 'object'):
      trani[i] = number.fit_transform(trani[i].astype('str'))
      trani[i] = trani[i].astype('object')

trani=trani.drop(['id','hospital_beds_raion'],axis=1)

# %%
print(trani.head())
# Out:
#    timestamp  full_sq  life_sq  ...  sport_count_5000  market_count_5000  price_doc
# 0          0       43     27.0  ...                52                  4    5850000
# 1          1       34     19.0  ...                66                 14    6000000
# 2          2       43     29.0  ...                67                 10    5700000
# 3          3       89     50.0  ...                26                  3   13100000
# 4          4       77     77.0  ...               195                 14   16331452
#
# [5 rows x 290 columns]

# %%
Z=trani.iloc[:,:-1]
M=trani.iloc[:,-1]

# Split the data into training and testing sets
Z_train, Z_test, M_train, M_test = train_test_split(Z,M, test_size = 0.25, random_state = 42)

# Instantiate model with 200 decision trees
drf = RandomForestRegressor(n_estimators = 100, random_state = 10)

##Fitting the model
drf.fit(Z_train, M_train);

# %%
# Use the forest's predict method on the test data
drf_predictions = drf.predict(Z_test)

print("Training Accuracy = ", drf.score(Z_train, M_train))


#errors = abs(predictions - y_test)
# Calculate mean absolute percentage error (MAPE)
#mape = 100 * (errors / y_test)
# Calculate and display accuracy
#accuracy = 100 - np.mean(mape)
#print('Accuracy for training before the dropping of features:', round(accuracy, 2), '%.')
# Out:
# Training Accuracy =  0.9544199997365559
